# %% [markdown]
# # Data Scientist Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
#
# This notebook walks you through one of the most popular Udacity projects across machine learning and artificial intellegence nanodegree programs.  The goal is to classify images of dogs according to their breed.
#
# If you are looking for a more guided capstone project related to deep learning and convolutional neural networks, this might be just it.  Notice that even if you follow the notebook to creating your classifier, you must still create a blog post or deploy an application to fulfill the requirements of the capstone project.
#
# Also notice, you may be able to use only parts of this notebook (for example certain coding portions or the data) without completing all parts and still meet all requirements of the capstone project.
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
#importing libraries

import numpy as np
from glob import glob
import random
import cv2                
import matplotlib.pyplot as plt                        
from tqdm import tqdm
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image                  
from keras.utils import np_utils
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from sklearn.datasets import load_files
from keras.layers import Dropout
from extract_bottleneck_features import *
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint


from PIL import ImageFile     
import pandas as pd

# %matplotlib inline

# %%
# define function to load train, test, and validation datasets
def load_dataset(path):
    '''
    This function is for loading dataset.
    
    Input: File Path
    Output: Datast
    '''
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %%
def dog_db(dataset):
    list_names = []
    num_files = []
    dog_db = pd.DataFrame()

    for  folder in sorted((glob("dogImages/"+dataset+"/*/"))):
        list_names.append(folder[20:-1])
        num_files.append(len(folder))    
    dog_db['breed_name'] = list_names
    dog_db['num_images'] = num_files
    return dog_db

# %%
dog = dog_db('train')
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
plt.bar(dog['breed_name'],dog['num_images'])
plt.show()

# %%
dog.sort_values(['breed_name', 'num_images'], ascending=False).groupby('breed_name').head(1)
# Out:
#                       breed_name  num_images
# 132            Yorkshire_terrier          38
# 131               Xoloitzcuintli          35
# 130  Wirehaired_pointing_griffon          48
# 129       Welsh_springer_spaniel          43
# 128              Tibetan_mastiff          36
# ..                           ...         ...
# 4               Alaskan_malamute          37
# 3                          Akita          26
# 2               Airedale_terrier          37
# 1                   Afghan_hound          33
# 0                  Affenpinscher          34
#
# [133 rows x 2 columns]

# %%
top_images = dog.nlargest(10, 'num_images')

# %%
top_images.head(5)
# Out:
#                              breed_name  num_images
# 111  Nova_scotia_duck_tolling_retriever          55
# 7        American_staffordshire_terrier          51
# 45        Cavalier_king_charles_spaniel          50
# 118        Petit_basset_griffon_vendeen          49
# 130         Wirehaired_pointing_griffon          48

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=90, size = 15)
plt.bar(top_images['breed_name'],top_images['num_images'])
plt.show()

# %%
dog.describe()
# Out:
#        num_images
# count  133.000000
# mean    36.203008
# std      5.984525
# min     26.000000
# 25%     31.000000
# 50%     36.000000
# 75%     40.000000
# max     55.000000

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):

    '''
    This function returns "True" if face is detected in image stored at img_path.
    
    Input: image Path
    Output: Boolean
    
    '''

    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
print(str(np.sum([face_detector(file) for file in tqdm(human_files_short)])) + '% of human images with a detected face')
print(str(np.sum([face_detector(file) for file in tqdm(dog_files_short)])) + '% of dog images with a detected face')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 28.88it/s]
#   2%|█▋                                                                                | 2/100 [00:00<00:07, 12.68it/s]
# 99% of human images with a detected face
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:13<00:00,  7.42it/s]
# 12% of dog images with a detected face

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %%
# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
def path_to_tensor(img_path):
    '''
    This function is for Converting 3D Tensor to 4D Tensor .
    
    Input: Image Path
    Output: 4D Tensor
    
    '''
    
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    '''
    This function is for providing lists of Tensors.
    
    Input: Image Path
    Output: Datast
    
    '''
    
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
def ResNet50_predict_labels(img_path):
    '''
    This function returns prediction vector for image located at img_path.
    
    Input: Image path Path
    Output: Prediction Vector
    '''
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__  We can see
#
# -  There is no dog face detected in 1st 100 Human_files_short
# -  There is no Human face detected in 1st 100 dog_files_short

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

humans_in_human_file = [dog_detector(img) for img in human_files_short]
dogs_in_dogs_file = [dog_detector(img) for img in dog_files_short]

print('percentage of dog face in human files is : {}%'.format(sum(humans_in_human_file)))
print('percentage of dog faces in 1st 100 dog files is : {}%'.format(sum(dogs_in_dogs_file)))
# Out:
# percentage of dog face in human files is : 0%
# percentage of dog faces in 1st 100 dog files is : 100%

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 6680/6680 [01:44<00:00, 63.92it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 835/835 [00:12<00:00, 69.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 836/836 [00:11<00:00, 71.69it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__ I used 3 Convolutional Layers with 16, 32, 64 filters respectively in order to discover features from the images. And between these layers I added a Max Pooling Layer.  At the end I used a Dense Layer with a ReLU activation function and for the output layer I used a softmax activation function to get results in percentage.

# %%
model = Sequential()

### TODO: Define your architecture.

model.add(Conv2D(16, kernel_size = (3,3), strides = (1,1), activation = 'relu', input_shape = (224, 224, 3)))
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2)))

model.add(Conv2D(32, kernel_size = (3,3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64, kernel_size = (3,3),  activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Dropout(0.3))

model.add(GlobalAveragePooling2D())

model.add(Dense(300, activation='relu'))

model.add(Dropout(0.4))

model.add(Dense(133, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 52, 52, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 26, 26, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               19500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               40033
# =================================================================
# Total params: 83,117
# Trainable params: 83,117
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 4

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/4
# 334/334 [==============================] - 170s 504ms/step - loss: 4.8873 - accuracy: 0.0093 - val_loss: 4.8728 - val_accuracy: 0.0108
#
# Epoch 00001: val_loss improved from inf to 4.87284, saving model to saved_models\weights.best.from_scratch.hdf5
# Epoch 2/4
# 334/334 [==============================] - 168s 502ms/step - loss: 4.8673 - accuracy: 0.0127 - val_loss: 4.8459 - val_accuracy: 0.0192
#
# Epoch 00002: val_loss improved from 4.87284 to 4.84593, saving model to saved_models\weights.best.from_scratch.hdf5
# Epoch 3/4
# 334/334 [==============================] - 166s 498ms/step - loss: 4.8243 - accuracy: 0.0197 - val_loss: 4.7645 - val_accuracy: 0.0228
#
# Epoch 00003: val_loss improved from 4.84593 to 4.76449, saving model to saved_models\weights.best.from_scratch.hdf5
# Epoch 4/4
# 334/334 [==============================] - 157s 471ms/step - loss: 4.7386 - accuracy: 0.0184 - val_loss: 4.8387 - val_accuracy: 0.0204
#
# Epoch 00004: val_loss did not improve from 4.76449

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 2.3923%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
#!pip install wget
#import wget
#url='https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz'
#wget.download(url)

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/20
# 334/334 [==============================] - 2s 4ms/step - loss: 13.2382 - accuracy: 0.1027 - val_loss: 3.6997 - val_accuracy: 0.4228
#
# Epoch 00001: val_loss improved from inf to 3.69965, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 2/20
# 334/334 [==============================] - 1s 4ms/step - loss: 2.3661 - accuracy: 0.5713 - val_loss: 2.5394 - val_accuracy: 0.5856
#
# Epoch 00002: val_loss improved from 3.69965 to 2.53943, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 3/20
# 334/334 [==============================] - 1s 4ms/step - loss: 1.2023 - accuracy: 0.7471 - val_loss: 2.4504 - val_accuracy: 0.6156
#
# Epoch 00003: val_loss improved from 2.53943 to 2.45040, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 4/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.7712 - accuracy: 0.8142 - val_loss: 2.1185 - val_accuracy: 0.6515
#
# Epoch 00004: val_loss improved from 2.45040 to 2.11852, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 5/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.5051 - accuracy: 0.8731 - val_loss: 1.9700 - val_accuracy: 0.6790
#
# Epoch 00005: val_loss improved from 2.11852 to 1.97004, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 6/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.3807 - accuracy: 0.8973 - val_loss: 2.0340 - val_accuracy: 0.6635
#
# Epoch 00006: val_loss did not improve from 1.97004
# Epoch 7/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.2538 - accuracy: 0.9268 - val_loss: 1.9380 - val_accuracy: 0.6994
#
# Epoch 00007: val_loss improved from 1.97004 to 1.93799, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 8/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1965 - accuracy: 0.9443 - val_loss: 1.9333 - val_accuracy: 0.6970
#
# Epoch 00008: val_loss improved from 1.93799 to 1.93328, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 9/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1396 - accuracy: 0.9543 - val_loss: 1.8785 - val_accuracy: 0.7066
#
# Epoch 00009: val_loss improved from 1.93328 to 1.87846, saving model to saved_models\weights.best.VGG16.hdf5
# Epoch 10/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1126 - accuracy: 0.9667 - val_loss: 1.9664 - val_accuracy: 0.6958
#
# Epoch 00010: val_loss did not improve from 1.87846
# Epoch 11/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.1024 - accuracy: 0.9681 - val_loss: 2.0385 - val_accuracy: 0.7150
#
# Epoch 00011: val_loss did not improve from 1.87846
# Epoch 12/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0623 - accuracy: 0.9797 - val_loss: 1.9260 - val_accuracy: 0.7114
#
# Epoch 00012: val_loss did not improve from 1.87846
# Epoch 13/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0669 - accuracy: 0.9822 - val_loss: 2.0854 - val_accuracy: 0.7078
#
# Epoch 00013: val_loss did not improve from 1.87846
# Epoch 14/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0373 - accuracy: 0.9893 - val_loss: 2.1471 - val_accuracy: 0.7162
#
# Epoch 00014: val_loss did not improve from 1.87846
# Epoch 15/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0417 - accuracy: 0.9866 - val_loss: 2.0138 - val_accuracy: 0.7293
#
# Epoch 00015: val_loss did not improve from 1.87846
# Epoch 16/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 2.0697 - val_accuracy: 0.7281
#
# Epoch 00016: val_loss did not improve from 1.87846
# Epoch 17/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0290 - accuracy: 0.9918 - val_loss: 2.0601 - val_accuracy: 0.7281
#
# Epoch 00017: val_loss did not improve from 1.87846
# Epoch 18/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0191 - accuracy: 0.9948 - val_loss: 2.0819 - val_accuracy: 0.7269
#
# Epoch 00018: val_loss did not improve from 1.87846
# Epoch 19/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 2.0775 - val_accuracy: 0.7150
#
# Epoch 00019: val_loss did not improve from 1.87846
# Epoch 20/20
# 334/334 [==============================] - 1s 4ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 2.2312 - val_accuracy: 0.7425
#
# Epoch 00020: val_loss did not improve from 1.87846

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 70.8134%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
#!pip install wget
#import wget
#url='https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz'
#wget.download(url)

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.

bottleneck_features = np.load('bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features['train']
valid_Xception = bottleneck_features['valid']
test_Xception = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.

Xception_model = Sequential()
Xception_model.add(GlobalAveragePooling2D(input_shape=train_Xception.shape[1:]))
Xception_model.add(Dropout(0.3))
Xception_model.add(Dense(500, activation='relu'))
Xception_model.add(Dropout(0.4))
Xception_model.add(Dense(133, activation='softmax'))

Xception_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               1024500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 133)               66633
# =================================================================
# Total params: 1,091,133
# Trainable params: 1,091,133
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Xception_model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.002), metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Xception.hdf5', 
                               verbose=1, save_best_only=True)

Xception_model.fit(train_Xception, train_targets, 
          validation_data=(valid_Xception, valid_targets),
          epochs=120, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/120
# 334/334 [==============================] - 5s 13ms/step - loss: 5.0134 - accuracy: 0.0131 - val_loss: 4.5979 - val_accuracy: 0.1246
#
# Epoch 00001: val_loss improved from inf to 4.59794, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 2/120
# 334/334 [==============================] - 4s 11ms/step - loss: 4.6274 - accuracy: 0.0594 - val_loss: 4.2533 - val_accuracy: 0.3269
#
# Epoch 00002: val_loss improved from 4.59794 to 4.25327, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 3/120
# 334/334 [==============================] - 4s 11ms/step - loss: 4.3069 - accuracy: 0.1515 - val_loss: 3.8743 - val_accuracy: 0.4743
#
# Epoch 00003: val_loss improved from 4.25327 to 3.87433, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 4/120
# 334/334 [==============================] - 4s 11ms/step - loss: 3.9113 - accuracy: 0.2719 - val_loss: 3.4497 - val_accuracy: 0.5497
#
# Epoch 00004: val_loss improved from 3.87433 to 3.44965, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 5/120
# 334/334 [==============================] - 4s 11ms/step - loss: 3.5420 - accuracy: 0.3870 - val_loss: 3.0029 - val_accuracy: 0.5952
#
# Epoch 00005: val_loss improved from 3.44965 to 3.00293, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 6/120
# 334/334 [==============================] - 4s 11ms/step - loss: 3.1135 - accuracy: 0.4622 - val_loss: 2.5702 - val_accuracy: 0.6419
#
# Epoch 00006: val_loss improved from 3.00293 to 2.57015, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 7/120
# 334/334 [==============================] - 4s 11ms/step - loss: 2.7214 - accuracy: 0.5262 - val_loss: 2.1853 - val_accuracy: 0.6731
#
# Epoch 00007: val_loss improved from 2.57015 to 2.18532, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 8/120
# 334/334 [==============================] - 4s 12ms/step - loss: 2.3733 - accuracy: 0.5727 - val_loss: 1.8653 - val_accuracy: 0.6922
#
# Epoch 00008: val_loss improved from 2.18532 to 1.86526, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 9/120
# 334/334 [==============================] - 4s 11ms/step - loss: 2.0829 - accuracy: 0.6167 - val_loss: 1.6085 - val_accuracy: 0.7281
#
# Epoch 00009: val_loss improved from 1.86526 to 1.60854, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 10/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.8384 - accuracy: 0.6473 - val_loss: 1.4077 - val_accuracy: 0.7485
#
# Epoch 00010: val_loss improved from 1.60854 to 1.40772, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 11/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.6571 - accuracy: 0.6707 - val_loss: 1.2525 - val_accuracy: 0.7641
#
# Epoch 00011: val_loss improved from 1.40772 to 1.25254, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 12/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.5310 - accuracy: 0.6833 - val_loss: 1.1298 - val_accuracy: 0.7749
#
# Epoch 00012: val_loss improved from 1.25254 to 1.12979, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 13/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.3757 - accuracy: 0.7105 - val_loss: 1.0338 - val_accuracy: 0.7892
#
# Epoch 00013: val_loss improved from 1.12979 to 1.03383, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 14/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.2952 - accuracy: 0.7108 - val_loss: 0.9572 - val_accuracy: 0.7976
#
# Epoch 00014: val_loss improved from 1.03383 to 0.95718, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 15/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.1935 - accuracy: 0.7299 - val_loss: 0.8962 - val_accuracy: 0.7976
#
# Epoch 00015: val_loss improved from 0.95718 to 0.89618, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 16/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.1092 - accuracy: 0.7376 - val_loss: 0.8453 - val_accuracy: 0.8024
#
# Epoch 00016: val_loss improved from 0.89618 to 0.84535, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 17/120
# 334/334 [==============================] - 4s 12ms/step - loss: 1.0498 - accuracy: 0.7552 - val_loss: 0.8048 - val_accuracy: 0.8060
#
# Epoch 00017: val_loss improved from 0.84535 to 0.80478, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 18/120
# 334/334 [==============================] - 4s 11ms/step - loss: 1.0168 - accuracy: 0.7579 - val_loss: 0.7694 - val_accuracy: 0.8120
#
# Epoch 00018: val_loss improved from 0.80478 to 0.76936, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 19/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.9451 - accuracy: 0.7625 - val_loss: 0.7387 - val_accuracy: 0.8216
#
# Epoch 00019: val_loss improved from 0.76936 to 0.73870, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 20/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.8953 - accuracy: 0.7729 - val_loss: 0.7127 - val_accuracy: 0.8204
#
# Epoch 00020: val_loss improved from 0.73870 to 0.71269, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 21/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.8802 - accuracy: 0.7826 - val_loss: 0.6923 - val_accuracy: 0.8228
#
# Epoch 00021: val_loss improved from 0.71269 to 0.69226, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 22/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.8904 - accuracy: 0.7749 - val_loss: 0.6732 - val_accuracy: 0.8240
#
# Epoch 00022: val_loss improved from 0.69226 to 0.67321, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 23/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.8326 - accuracy: 0.7819 - val_loss: 0.6542 - val_accuracy: 0.8287
#
# Epoch 00023: val_loss improved from 0.67321 to 0.65420, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 24/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.8180 - accuracy: 0.7883 - val_loss: 0.6397 - val_accuracy: 0.8371
#
# Epoch 00024: val_loss improved from 0.65420 to 0.63969, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 25/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.8089 - accuracy: 0.7848 - val_loss: 0.6252 - val_accuracy: 0.8407
#
# Epoch 00025: val_loss improved from 0.63969 to 0.62522, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 26/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.7736 - accuracy: 0.7869 - val_loss: 0.6125 - val_accuracy: 0.8407
#
# Epoch 00026: val_loss improved from 0.62522 to 0.61249, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 27/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.7826 - accuracy: 0.7941 - val_loss: 0.6030 - val_accuracy: 0.8431
#
# Epoch 00027: val_loss improved from 0.61249 to 0.60299, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 28/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.7478 - accuracy: 0.7987 - val_loss: 0.5933 - val_accuracy: 0.8383
#
# Epoch 00028: val_loss improved from 0.60299 to 0.59332, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 29/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.7053 - accuracy: 0.8120 - val_loss: 0.5833 - val_accuracy: 0.8431
#
# Epoch 00029: val_loss improved from 0.59332 to 0.58328, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 30/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.7056 - accuracy: 0.8095 - val_loss: 0.5746 - val_accuracy: 0.8467
#
# Epoch 00030: val_loss improved from 0.58328 to 0.57456, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 31/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.7024 - accuracy: 0.8027 - val_loss: 0.5684 - val_accuracy: 0.8503
#
# Epoch 00031: val_loss improved from 0.57456 to 0.56836, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 32/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.6987 - accuracy: 0.8075 - val_loss: 0.5613 - val_accuracy: 0.8515
#
# Epoch 00032: val_loss improved from 0.56836 to 0.56128, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 33/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.6744 - accuracy: 0.8069 - val_loss: 0.5556 - val_accuracy: 0.8491
#
# Epoch 00033: val_loss improved from 0.56128 to 0.55558, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 34/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.6554 - accuracy: 0.8173 - val_loss: 0.5484 - val_accuracy: 0.8479
#
# Epoch 00034: val_loss improved from 0.55558 to 0.54845, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 35/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.6580 - accuracy: 0.8239 - val_loss: 0.5415 - val_accuracy: 0.8527
#
# Epoch 00035: val_loss improved from 0.54845 to 0.54146, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 36/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.6313 - accuracy: 0.8227 - val_loss: 0.5376 - val_accuracy: 0.8551
#
# Epoch 00036: val_loss improved from 0.54146 to 0.53761, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 37/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.6433 - accuracy: 0.8098 - val_loss: 0.5320 - val_accuracy: 0.8515
#
# Epoch 00037: val_loss improved from 0.53761 to 0.53196, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 38/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.6183 - accuracy: 0.8248 - val_loss: 0.5268 - val_accuracy: 0.8551
#
# Epoch 00038: val_loss improved from 0.53196 to 0.52680, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 39/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.6098 - accuracy: 0.8226 - val_loss: 0.5220 - val_accuracy: 0.8539
#
# Epoch 00039: val_loss improved from 0.52680 to 0.52199, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 40/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.6027 - accuracy: 0.8309 - val_loss: 0.5203 - val_accuracy: 0.8551
#
# Epoch 00040: val_loss improved from 0.52199 to 0.52029, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 41/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5935 - accuracy: 0.8282 - val_loss: 0.5132 - val_accuracy: 0.8563
#
# Epoch 00041: val_loss improved from 0.52029 to 0.51325, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 42/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5899 - accuracy: 0.8311 - val_loss: 0.5111 - val_accuracy: 0.8515
#
# Epoch 00042: val_loss improved from 0.51325 to 0.51110, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 43/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.5763 - accuracy: 0.8310 - val_loss: 0.5081 - val_accuracy: 0.8515
#
# Epoch 00043: val_loss improved from 0.51110 to 0.50806, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 44/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5685 - accuracy: 0.8403 - val_loss: 0.5048 - val_accuracy: 0.8527
#
# Epoch 00044: val_loss improved from 0.50806 to 0.50480, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 45/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5525 - accuracy: 0.8436 - val_loss: 0.5014 - val_accuracy: 0.8515
#
# Epoch 00045: val_loss improved from 0.50480 to 0.50140, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 46/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5574 - accuracy: 0.8339 - val_loss: 0.4993 - val_accuracy: 0.8551
#
# Epoch 00046: val_loss improved from 0.50140 to 0.49935, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 47/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5675 - accuracy: 0.8346 - val_loss: 0.4961 - val_accuracy: 0.8611
#
# Epoch 00047: val_loss improved from 0.49935 to 0.49610, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 48/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5675 - accuracy: 0.8374 - val_loss: 0.4948 - val_accuracy: 0.8551
#
# Epoch 00048: val_loss improved from 0.49610 to 0.49482, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 49/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.5541 - accuracy: 0.8356 - val_loss: 0.4901 - val_accuracy: 0.8575
#
# Epoch 00049: val_loss improved from 0.49482 to 0.49010, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 50/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5475 - accuracy: 0.8367 - val_loss: 0.4883 - val_accuracy: 0.8563
#
# Epoch 00050: val_loss improved from 0.49010 to 0.48834, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 51/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5316 - accuracy: 0.8450 - val_loss: 0.4863 - val_accuracy: 0.8575
#
# Epoch 00051: val_loss improved from 0.48834 to 0.48634, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 52/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5430 - accuracy: 0.8340 - val_loss: 0.4837 - val_accuracy: 0.8575
#
# Epoch 00052: val_loss improved from 0.48634 to 0.48365, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 53/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5201 - accuracy: 0.8505 - val_loss: 0.4825 - val_accuracy: 0.8599
#
# Epoch 00053: val_loss improved from 0.48365 to 0.48249, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 54/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4853 - accuracy: 0.8607 - val_loss: 0.4792 - val_accuracy: 0.8611
#
# Epoch 00054: val_loss improved from 0.48249 to 0.47919, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 55/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5142 - accuracy: 0.8480 - val_loss: 0.4785 - val_accuracy: 0.8575
#
# Epoch 00055: val_loss improved from 0.47919 to 0.47850, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 56/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.5043 - accuracy: 0.8508 - val_loss: 0.4762 - val_accuracy: 0.8539
#
# Epoch 00056: val_loss improved from 0.47850 to 0.47623, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 57/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5041 - accuracy: 0.8567 - val_loss: 0.4738 - val_accuracy: 0.8551
#
# Epoch 00057: val_loss improved from 0.47623 to 0.47383, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 58/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5025 - accuracy: 0.8553 - val_loss: 0.4736 - val_accuracy: 0.8539
#
# Epoch 00058: val_loss improved from 0.47383 to 0.47362, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 59/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.5158 - accuracy: 0.8454 - val_loss: 0.4700 - val_accuracy: 0.8563
#
# Epoch 00059: val_loss improved from 0.47362 to 0.47003, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 60/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4747 - accuracy: 0.8583 - val_loss: 0.4682 - val_accuracy: 0.8539
#
# Epoch 00060: val_loss improved from 0.47003 to 0.46825, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 61/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4814 - accuracy: 0.8523 - val_loss: 0.4671 - val_accuracy: 0.8599
#
# Epoch 00061: val_loss improved from 0.46825 to 0.46712, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 62/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4807 - accuracy: 0.8563 - val_loss: 0.4660 - val_accuracy: 0.8587
#
# Epoch 00062: val_loss improved from 0.46712 to 0.46601, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 63/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4679 - accuracy: 0.8626 - val_loss: 0.4643 - val_accuracy: 0.8587
#
# Epoch 00063: val_loss improved from 0.46601 to 0.46434, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 64/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4442 - accuracy: 0.8677 - val_loss: 0.4646 - val_accuracy: 0.8527
#
# Epoch 00064: val_loss did not improve from 0.46434
# Epoch 65/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4712 - accuracy: 0.8576 - val_loss: 0.4638 - val_accuracy: 0.8551
#
# Epoch 00065: val_loss improved from 0.46434 to 0.46376, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 66/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4716 - accuracy: 0.8632 - val_loss: 0.4611 - val_accuracy: 0.8563
#
# Epoch 00066: val_loss improved from 0.46376 to 0.46107, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 67/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4605 - accuracy: 0.8645 - val_loss: 0.4608 - val_accuracy: 0.8563
#
# Epoch 00067: val_loss improved from 0.46107 to 0.46081, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 68/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4596 - accuracy: 0.8603 - val_loss: 0.4598 - val_accuracy: 0.8563
#
# Epoch 00068: val_loss improved from 0.46081 to 0.45983, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 69/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4683 - accuracy: 0.8555 - val_loss: 0.4573 - val_accuracy: 0.8599
#
# Epoch 00069: val_loss improved from 0.45983 to 0.45731, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 70/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4331 - accuracy: 0.8682 - val_loss: 0.4579 - val_accuracy: 0.8527
#
# Epoch 00070: val_loss did not improve from 0.45731
# Epoch 71/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4272 - accuracy: 0.8781 - val_loss: 0.4571 - val_accuracy: 0.8551
#
# Epoch 00071: val_loss improved from 0.45731 to 0.45709, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 72/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4531 - accuracy: 0.8617 - val_loss: 0.4564 - val_accuracy: 0.8551
#
# Epoch 00072: val_loss improved from 0.45709 to 0.45640, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 73/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4381 - accuracy: 0.8651 - val_loss: 0.4526 - val_accuracy: 0.8599
#
# Epoch 00073: val_loss improved from 0.45640 to 0.45264, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 74/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4370 - accuracy: 0.8700 - val_loss: 0.4528 - val_accuracy: 0.8575
#
# Epoch 00074: val_loss did not improve from 0.45264
# Epoch 75/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4079 - accuracy: 0.8758 - val_loss: 0.4524 - val_accuracy: 0.8599
#
# Epoch 00075: val_loss improved from 0.45264 to 0.45240, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 76/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4284 - accuracy: 0.8728 - val_loss: 0.4524 - val_accuracy: 0.8587
#
# Epoch 00076: val_loss improved from 0.45240 to 0.45236, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 77/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4388 - accuracy: 0.8645 - val_loss: 0.4525 - val_accuracy: 0.8587
#
# Epoch 00077: val_loss did not improve from 0.45236
# Epoch 78/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4273 - accuracy: 0.8715 - val_loss: 0.4501 - val_accuracy: 0.8575
#
# Epoch 00078: val_loss improved from 0.45236 to 0.45010, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 79/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4114 - accuracy: 0.8774 - val_loss: 0.4494 - val_accuracy: 0.8611
#
# Epoch 00079: val_loss improved from 0.45010 to 0.44936, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 80/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4253 - accuracy: 0.8715 - val_loss: 0.4475 - val_accuracy: 0.8575
#
# Epoch 00080: val_loss improved from 0.44936 to 0.44752, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 81/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4344 - accuracy: 0.8663 - val_loss: 0.4461 - val_accuracy: 0.8599
#
# Epoch 00081: val_loss improved from 0.44752 to 0.44608, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 82/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3998 - accuracy: 0.8819 - val_loss: 0.4441 - val_accuracy: 0.8623
#
# Epoch 00082: val_loss improved from 0.44608 to 0.44408, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 83/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4021 - accuracy: 0.8753 - val_loss: 0.4435 - val_accuracy: 0.8623
#
# Epoch 00083: val_loss improved from 0.44408 to 0.44347, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 84/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4090 - accuracy: 0.8816 - val_loss: 0.4445 - val_accuracy: 0.8611
#
# Epoch 00084: val_loss did not improve from 0.44347
# Epoch 85/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4180 - accuracy: 0.8703 - val_loss: 0.4423 - val_accuracy: 0.8599
#
# Epoch 00085: val_loss improved from 0.44347 to 0.44229, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 86/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4100 - accuracy: 0.8756 - val_loss: 0.4420 - val_accuracy: 0.8623
#
# Epoch 00086: val_loss improved from 0.44229 to 0.44198, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 87/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.4132 - accuracy: 0.8711 - val_loss: 0.4411 - val_accuracy: 0.8635
#
# Epoch 00087: val_loss improved from 0.44198 to 0.44113, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 88/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.3976 - accuracy: 0.8807 - val_loss: 0.4409 - val_accuracy: 0.8635
#
# Epoch 00088: val_loss improved from 0.44113 to 0.44091, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 89/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4006 - accuracy: 0.8733 - val_loss: 0.4408 - val_accuracy: 0.8599
#
# Epoch 00089: val_loss improved from 0.44091 to 0.44082, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 90/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4190 - accuracy: 0.8701 - val_loss: 0.4400 - val_accuracy: 0.8575
#
# Epoch 00090: val_loss improved from 0.44082 to 0.44004, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 91/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.3799 - accuracy: 0.8884 - val_loss: 0.4405 - val_accuracy: 0.8599
#
# Epoch 00091: val_loss did not improve from 0.44004
# Epoch 92/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.4046 - accuracy: 0.8840 - val_loss: 0.4402 - val_accuracy: 0.8647
#
# Epoch 00092: val_loss did not improve from 0.44004
# Epoch 93/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.3621 - accuracy: 0.8906 - val_loss: 0.4390 - val_accuracy: 0.8623
#
# Epoch 00093: val_loss improved from 0.44004 to 0.43897, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 94/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3811 - accuracy: 0.8886 - val_loss: 0.4389 - val_accuracy: 0.8647
#
# Epoch 00094: val_loss improved from 0.43897 to 0.43887, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 95/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.3935 - accuracy: 0.8765 - val_loss: 0.4387 - val_accuracy: 0.8611
#
# Epoch 00095: val_loss improved from 0.43887 to 0.43873, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 96/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3768 - accuracy: 0.8916 - val_loss: 0.4370 - val_accuracy: 0.8575
#
# Epoch 00096: val_loss improved from 0.43873 to 0.43699, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 97/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.3881 - accuracy: 0.8767 - val_loss: 0.4376 - val_accuracy: 0.8575
#
# Epoch 00097: val_loss did not improve from 0.43699
# Epoch 98/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3736 - accuracy: 0.8911 - val_loss: 0.4351 - val_accuracy: 0.8623
# Epoch 00098: val_loss improved from 0.43699 to 0.43512, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 99/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3833 - accuracy: 0.8798 - val_loss: 0.4335 - val_accuracy: 0.8623
#
# Epoch 00099: val_loss improved from 0.43512 to 0.43349, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 100/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3623 - accuracy: 0.8888 - val_loss: 0.4351 - val_accuracy: 0.8647
#
# Epoch 00100: val_loss did not improve from 0.43349
# Epoch 101/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3792 - accuracy: 0.8879 - val_loss: 0.4348 - val_accuracy: 0.8599
#
# Epoch 00101: val_loss did not improve from 0.43349
# Epoch 102/120
# 334/334 [==============================] - 4s 12ms/step - loss: 0.3743 - accuracy: 0.8881 - val_loss: 0.4351 - val_accuracy: 0.8611
#
# Epoch 00102: val_loss did not improve from 0.43349
# Epoch 103/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3476 - accuracy: 0.8935 - val_loss: 0.4330 - val_accuracy: 0.8623
#
# Epoch 00103: val_loss improved from 0.43349 to 0.43296, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 104/120
# 334/334 [==============================] - 4s 10ms/step - loss: 0.3560 - accuracy: 0.8903 - val_loss: 0.4334 - val_accuracy: 0.8635
#
# Epoch 00104: val_loss did not improve from 0.43296
# Epoch 105/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3666 - accuracy: 0.8892 - val_loss: 0.4332 - val_accuracy: 0.8623
#
# Epoch 00105: val_loss did not improve from 0.43296
# Epoch 106/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3515 - accuracy: 0.8933 - val_loss: 0.4335 - val_accuracy: 0.8575
#
# Epoch 00106: val_loss did not improve from 0.43296
# Epoch 107/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3526 - accuracy: 0.8888 - val_loss: 0.4315 - val_accuracy: 0.8599
#
# Epoch 00107: val_loss improved from 0.43296 to 0.43153, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 108/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3617 - accuracy: 0.8891 - val_loss: 0.4338 - val_accuracy: 0.8623
#
# Epoch 00108: val_loss did not improve from 0.43153
# Epoch 109/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3452 - accuracy: 0.8939 - val_loss: 0.4322 - val_accuracy: 0.8635
#
# Epoch 00109: val_loss did not improve from 0.43153
# Epoch 110/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3517 - accuracy: 0.8922 - val_loss: 0.4295 - val_accuracy: 0.8635
#
# Epoch 00110: val_loss improved from 0.43153 to 0.42946, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 111/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3459 - accuracy: 0.8946 - val_loss: 0.4307 - val_accuracy: 0.8623
#
# Epoch 00111: val_loss did not improve from 0.42946
# Epoch 112/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3438 - accuracy: 0.8937 - val_loss: 0.4303 - val_accuracy: 0.8647
#
# Epoch 00112: val_loss did not improve from 0.42946
# Epoch 113/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3411 - accuracy: 0.8925 - val_loss: 0.4315 - val_accuracy: 0.8599
#
# Epoch 00113: val_loss did not improve from 0.42946
# Epoch 114/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3557 - accuracy: 0.8915 - val_loss: 0.4318 - val_accuracy: 0.8599
#
# Epoch 00114: val_loss did not improve from 0.42946
# Epoch 115/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3419 - accuracy: 0.8986 - val_loss: 0.4318 - val_accuracy: 0.8611
#
# Epoch 00115: val_loss did not improve from 0.42946
# Epoch 116/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3348 - accuracy: 0.9005 - val_loss: 0.4298 - val_accuracy: 0.8623
#
# Epoch 00116: val_loss did not improve from 0.42946
# Epoch 117/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3218 - accuracy: 0.9018 - val_loss: 0.4289 - val_accuracy: 0.8635
#
# Epoch 00117: val_loss improved from 0.42946 to 0.42893, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 118/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3314 - accuracy: 0.8956 - val_loss: 0.4282 - val_accuracy: 0.8623
#
# Epoch 00118: val_loss improved from 0.42893 to 0.42819, saving model to saved_models\weights.best.Xception.hdf5
# Epoch 119/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3348 - accuracy: 0.8991 - val_loss: 0.4295 - val_accuracy: 0.8635
#
# Epoch 00119: val_loss did not improve from 0.42819
# Epoch 120/120
# 334/334 [==============================] - 4s 11ms/step - loss: 0.3337 - accuracy: 0.8924 - val_loss: 0.4279 - val_accuracy: 0.8647
#
# Epoch 00120: val_loss improved from 0.42819 to 0.42793, saving model to saved_models\weights.best.Xception.hdf5

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Xception_model.load_weights('saved_models/weights.best.Xception.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set
Xception_predictions = [np.argmax(Xception_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Xception]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Xception_predictions)==np.argmax(test_targets, axis=1))/len(Xception_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 85.6459%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

def Xception_predict_breed(img_path):
    #extract bottleneck features
    bottleneck_feature = extract_Xception(path_to_tensor(img_path))
    print(bottleneck_feature.shape) 
    #returns (1, 2048)
    
    #obtain predicted vector
    predicted_vector = Xception_model.predict(bottleneck_feature) #shape error occurs here
    
    #return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# A sample image and output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_2.png)
#
# This photo looks like an Afghan Hound.
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
def display_img(img_path):
    
    '''
    This function is for displaying Image.
    
    Input: Image Path
    Output: Plot Image
    '''

    img = cv2.imread(img_path)
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    imgplot = plt.imshow(cv_rgb)

def predict_breed(img_path):

    '''
    This function predict the dog breed.
    
    Input: Image path Path
    Output: Prediction Vector
    '''

    display_img(img_path)
    if dog_detector(img_path):
        print("I detected a dog!")
        return print("The breed of this dog is a {}".format(Xception_predict_breed(img_path)))
        
    if face_detector(img_path):
        #return print("If you were a dog you would be a ... {}!!".format(Xception_predict_breed(img_path)))
        return print("I detected a human!")
        
    else:
        return print("No Human or dog detected")

# %%
def predict_breed_vga(img_path):

    '''
    This function predict the dog breed.
    
    Input: Image path Path
    Output: Prediction Vector
    '''

    display_img(img_path)
    if dog_detector(img_path):
        print("I detected a dog!")
        return print("The breed of this dog is a {}".format(VGG16_predict_breed(img_path)))
        
    if face_detector(img_path):
        #return print("If you were a dog you would be a ... {}!!".format(Xception_predict_breed(img_path)))
        return print("I detected a human!")
        
    else:
        return print("No Human or dog detected")

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__ Output is Better than expected.
#
# - It can be improved by using the depth of network
# - Providing more trainig data
# - Train with different optimizers

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
predict_breed('images/Labrador_retriever_06455.jpg')
# Out:
# I detected a dog!
# (1, 7, 7, 2048)
# The breed of this dog is a Labrador_retriever

# %%
predict_breed('images/Siberian-Husky.jpg')
# Out:
# I detected a dog!
# (1, 7, 7, 2048)
# The breed of this dog is a Alaskan_malamute

# %%
predict_breed('images/German_Shepherd.jpg')
# Out:
# I detected a dog!
# (1, 7, 7, 2048)
# The breed of this dog is a German_shepherd_dog

# %%
predict_breed('images/dackel.jpg')
# Out:
# I detected a dog!
# WARNING:tensorflow:5 out of the last 847 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DB3A3C1DC8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1, 7, 7, 2048)
# The breed of this dog is a Dachshund

# %%
predict_breed('images/australian-shepherd.jpg')
# Out:
# I detected a dog!
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DB38880E58> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1, 7, 7, 2048)
# The breed of this dog is a Australian_shepherd

# %%
predict_breed('images/sample_human_2.png')
# Out:
# I detected a human!

# %%
predict_breed_vga('images/Siberian-Husky.jpg')
# Out:
# I detected a dog!
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 76s 1us/step
# The breed of this dog is a Alaskan_malamute

# %%
predict_breed_vga('images/sample_human_2.png')
# Out:
# I detected a human!
